# %%
import os
import random
import math
import time

# %%
class gate_dlinkedList:
    def __init__(self, gate_id, bucket_side, area):
        self.gate_id = gate_id
        self.bucket_side = bucket_side
        self.area = area
        self.lock = False
        self.gain = None
        self.next = None
        self.prev = None

    def set_next(self, next_gate):
        self.next = next_gate
        if next_gate:
            next_gate.prev = self
        return self.next
    
    def move_gate(self, new_gain):
        self.remove_gate()
        self.gain = new_gain
        
        if new_gain in self.bucket_side.keys():
            self.bucket_side[new_gain] = self.bucket_side[new_gain].set_next(self)
            self.bucket_side[new_gain].next = None
        else:
            self.bucket_side[new_gain] = self
            self.bucket_side[new_gain].next = None
            self.bucket_side[new_gain].prev = None
            
    def remove_gate(self):
        if self.gain in self.bucket_side.keys() and not self.next:
            if self.prev:
                self.bucket_side[self.gain] = self.prev
            else: #not self.prev
                del self.bucket_side[self.gain]
        if self.prev:
            self.prev.next = self.next
        if self.next:
            self.next.prev = self.prev
        self.next = None
        self.prev = None
        self.gain = None

    def __repr__(self):
        if self.next:
            next_id = self.next.gate_id  
        else:
            next_id = 'None'
        prev_id = self.prev.gate_id if self.prev else 'None'
        return f"Gate(Id:{self.gate_id},next:{next_id},prev:{prev_id},lock:{self.lock},gain:{self.gain})"

# %%
class readFile:
    def __init__(self):
        self.circuit_data = None
        
    def read_circuit(self, circuit_folder_path):
        netD_file = None
        are_file = None
        for file in os.listdir(circuit_folder_path):
            if file.endswith('.netD'):
                netD_file = os.path.join(circuit_folder_path, file)
            if file.endswith('.are'):
                are_file = os.path.join(circuit_folder_path, file)
        if netD_file and are_file:
            self.circuit_data = self.parse_net_files(netD_file, are_file)
            return self.circuit_data
        else:
            print("Error Message: Missing Files")
            return None

    def parse_net_files(self, netD_file, are_file):
        # network information
        nets_out, nets_in, connections, nodes, modules, pad_offset = self.read_netD_file(netD_file)
        # module areas
        areas = self.read_are_file(are_file)
        # network information with pin directions
        self.circuit_data = {
            'areas': areas,
            'netD_out': nets_out,
            'netD_in': nets_in,
            'connections': int(connections),
            'nodes': int(nodes),
            'modules': int(modules),
            'pad_offset': int(pad_offset)
        }
        return self.circuit_data
    
    def read_are_file(self, circuit_folder_path):
        with open(circuit_folder_path, 'r') as file:
            lines = file.readlines()
        module_areas = {}
        for line in lines:
            module_id, area = line.split()
            module_areas[module_id] = int(area)
        return module_areas

    def read_netD_file(self, circuit_folder_path):
        with open(circuit_folder_path, 'r') as file:
            lines = file.readlines()

        self.circuit_info = tuple(item.replace('\n', '') for item in lines[0:5])
        _, connections, nodes, modules, pad_offset = self.circuit_info
        lines = lines[5:]

        nets_out = {}
        nets_in = {}
        current_key = None


        for line in lines:
            tokens = line.split()

            #populate dictionaries
            if tokens[0] not in nets_out.keys():
                nets_out[tokens[0]] = []
            if tokens[0] not in nets_in.keys():
                nets_in[tokens[0]] = []

            if tokens[1] == 's':
                current_key = tokens[0]
            elif tokens[1] == 'l':
                #nets out
                nets_out[current_key].append(tokens[0])
                #nets in
                nets_in[tokens[0]].append(current_key)
            
        return nets_out, nets_in, connections, nodes, modules, pad_offset

# %%
class FM_algo:
    def __init__(self, circuit_folder_path, ratio = 0.5, tolerance = 0.1):
        self.start_time = time.time()
        self.circuit_data = readFile().read_circuit(circuit_folder_path)
        self.circuit_connections_in = self.circuit_data['netD_in']
        print('input connections', self.circuit_connections_in)
        self.circuit_connections_out = self.circuit_data['netD_out']
        print('output connections', self.circuit_connections_out)
        self.circuit_gate_areas = self.circuit_data['areas']
        self.ratio, self.tolerance = ratio, tolerance
        self.W = sum(self.circuit_gate_areas.values())
        self.s_max = max(self.circuit_gate_areas.values())
        self.k = self.tolerance * len(self.circuit_gate_areas) 
        self.bucket_count1, self.bucket_count2 = 0, 0
        self.bucket_gains1 = dict()
        self.bucket_gains2 = dict()
        self.vertex = dict()
        initial_cutsize, best_cutsize, improvement, iter_count = self.fd_algo()
        runtime = time.time() - self.start_time

        print(f'Initial Cut Size: {initial_cutsize}')
        print('Fiduccia-Mattheyses Algorithm Complete!')
        print(f'Runtime: {runtime} seconds')
        print(f'Best Cut Size: {best_cutsize}')
        print(f'Total number of iterations: {iter_count}')
        print(f'Improvement percentage: {improvement}%')
        print(f'Number of Gates in Bucket 1: {self.bucket_count1}')
        print(f'Number of Gates in Bucket 2: {self.bucket_count2}')
        
    def fd_algo(self):
        #partition circuit
        # self.partition1, self.partition2 = self.partition_circuit()
        self.partition1, self.partition2 = self.optimal_partition_circuit()
        print('parition1 ',self.partition1)
        print('parition2 ',self.partition2)
        #initialize buckets
        self.bucket_gains1 = self.initialize_buckets(self.partition1, self.bucket_gains1)
        self.bucket_gains2 = self.initialize_buckets(self.partition2, self.bucket_gains2)
        cutsize = self.calculate_cutsize()
        initial_cutsize = cutsize

        ##TODO: Begin Fiduccia-Mattheyses Algorithm below
        max_iter_count = 5
        iter_count = 0
        best_cutsize = float('inf') # Initialize the best cut size to inf
        
        while(True):
            iter_count += 1
            print(f"Number of Iterations: {iter_count}")
            last_cutsize = cutsize
            last_bucket1 = self.bucket_gains1
            last_bucket2 = self.bucket_gains2
            cutsize = self.fm_pass()
            if (cutsize < best_cutsize) and (math.isfinite(cutsize)): #if improvements
                best_cutsize = cutsize           
            if (cutsize >= last_cutsize) and (iter_count >= max_iter_count) or (last_cutsize == 1): #if no improvement
                #roll back to initial best buckets
                self.last_bucket1 = last_bucket1
                self.last_bucket2 = last_bucket2
                break   
            self.reinitialize_buckets()
        if math.isfinite(best_cutsize):
            improvement = round((1-best_cutsize/initial_cutsize)*100, 4)            
        return initial_cutsize, best_cutsize, improvement, iter_count
    
    def fm_pass(self):
        #initialize best cutsize
        best_cutsize = float('inf')
        best_bucket1 = self.bucket_gains1
        best_bucket2 = self.bucket_gains2

        #Reset parameters for optimization
        free_gates = self.circuit_gate_areas.copy()
        self.W = sum(self.circuit_gate_areas.values())
        self.s_max = max(self.circuit_gate_areas.values())
        self.k = self.tolerance * len(self.circuit_gate_areas) 
        locked_gates_count = 0

        while (not self.check_gate_locks(locked_gates_count)): #Stop if all gates are locked
            # max_gain_node, _ = self.calculate_max_gain()

            optimal_moves = self.get_optimal_moves(free_gates)

            if not optimal_moves:
                break

            optimal_max_gain_node = self.calculate_optimal_maxgain(optimal_moves)

            #move to opposite side of bucket && remove gate from bucket & lock gate
            optimal_max_gain_node.remove_gate()
            optimal_max_gain_node.lock = True
            locked_gates_count += 1
            print(f'FM progress: {locked_gates_count} / {len(self.vertex)}')
            if optimal_max_gain_node.bucket_side == self.bucket_gains1:
                optimal_max_gain_node.bucket_side = self.bucket_gains2
                self.bucket_count1 -= 1
                self.bucket_count2 += 1
            elif optimal_max_gain_node.bucket_side == self.bucket_gains2:
                optimal_max_gain_node.bucket_side = self.bucket_gains1
                self.bucket_count1 += 1
                self.bucket_count2 -= 1
                
            # Update gain locally for affected gates
            self.update_local_out_gains(optimal_max_gain_node)
            self.update_local_in_gains(optimal_max_gain_node)
            #TODO: Update W, s_max, and k as needed
            self.update_optimization_parameters(free_gates, optimal_max_gain_node.gate_id, locked_gates_count)
            current_cutsize = self.calculate_cutsize()
            #Rollback to best observed cutsize
            if current_cutsize < best_cutsize and current_cutsize >= 1:
                best_cutsize = current_cutsize
                best_bucket1 = self.bucket_gains1
                best_bucket2 = self.bucket_gains2

        self.bucket_gains1 = best_bucket1
        self.bucket_gains2 = best_bucket2
        new_cutsize = best_cutsize
        return new_cutsize
    
    def update_optimization_parameters(self, gate_areas, removed_gate, locks):
        del gate_areas[removed_gate]
        # Update W, s_max, and k as needed
        self.W = sum(self.circuit_gate_areas.values())
        self.s_max = max(self.circuit_gate_areas.values())
        num_free_cells = len(self.vertex) - locks
        self.k = self.tolerance * num_free_cells
        
    def calculate_optimal_maxgain(self, optimal_moves):
        if not optimal_moves: return None
        max_gain = self.vertex[optimal_moves[0][0]].gain
        optimal_balance = float('inf')
        optimal_gate_node = None
        
        partition_sum1 = self.get_partition_areasums(self.bucket_gains1)
        partition_sum2 = self.get_partition_areasums(self.bucket_gains2)
        for id, _ in optimal_moves:
            if self.vertex[id].gain != max_gain:
                break
            else:
                node = self.vertex[id]
                if node in self.bucket_gains1:
                    new_size1 = (partition_sum1) - node.area
                    new_size2 = (partition_sum2) + node.area
                else: # if node in self.bucket_gains2
                    new_size2 = (partition_sum2) - node.area
                    new_size1 = (partition_sum1) + node.area

                delta = abs((new_size1 - new_size2) - self.ratio * self.W)
                if delta < optimal_balance:
                    optimal_gate_node = self.vertex[id]


        return optimal_gate_node

    def update_local_out_gains(self, moved_gate):
        for net in self.circuit_connections_out[moved_gate.gate_id]:
            net_node = self.vertex[net]
            # Calculate new gain for the net
            new_gain = self.calculate_gain(net)
            # Update the gain of the gate in the same bucket
            net_node.move_gate(new_gain)

            net_node.gain = new_gain
        
    def update_local_in_gains(self, moved_gate):
        for net in self.circuit_connections_in[moved_gate.gate_id]:
            net_node = self.vertex[net]
            # Calculate new gain for the net
            new_gain = self.calculate_gain(net)
            # Update the gain of the gate in the same bucket
            net_node.move_gate(new_gain)

            net_node.gain = new_gain

    def reinitialize_buckets(self):
        for gate, node in self.vertex.items():
            #unlock gate
            node.lock = False
            gain = self.calculate_gain(gate)
            node.move_gate(gain)
            # if gain in node.bucket_side.keys():
            #     node.bucket_side[gain] = node.bucket_side[gain].set_next(node)    
            #     node.bucket_side[gain].next = None
            # else:
            #     node.bucket_side[gain] = node
            #     node.bucket_side[gain].prev = None
            #     node.bucket_side[gain].next = None


    def get_partition_areasums(self, partition):
        total_sums = 0
        for node in partition.values():
            current_node = node
            while current_node:
                total_sums += current_node.area
                current_node = current_node.prev
        return total_sums

    def check_gate_locks(self, locked_gates_count):
        # return True if all gates are locked
        return locked_gates_count == len(self.vertex) 

    def calculate_cutsize(self):
        cut_size = 0
        for gate, connected_gates in self.circuit_connections_out.items():
            current_gate_node = self.vertex[gate]
            current_gate_side = current_gate_node.bucket_side
            for connected_gate in connected_gates:
                connected_gate_node = self.vertex[connected_gate]
                connected_gate_side = connected_gate_node.bucket_side
                if current_gate_side != connected_gate_side:
                    cut_size += 1
                    break 
        return cut_size

    def calculate_max_gain(self):
        if self.bucket_gains1: max_gain1 = max(self.bucket_gains1.keys())
        else: max_gain1 = float('-inf')

        if self.bucket_gains2: max_gain2 = max(self.bucket_gains2.keys()) 
        else: max_gain2 = float('-inf')

        if max_gain1 > max_gain2: 
            selected_bucket = self.bucket_gains1  
        elif max_gain1 < max_gain2:
            selected_bucket = self.bucket_gains2
        else: #if max_gain1 == max_gain2 select the bigger bucket
            if self.bucket_count1 > self.bucket_count2:
                selected_bucket = self.bucket_gains1
            else: #self.bucket_count1 > self.bucket_count2
                selected_bucket = self.bucket_gains2

        overall_max_gain = max(max_gain1, max_gain2)

        if overall_max_gain != float('-inf'): max_gain_node = selected_bucket[overall_max_gain]  
        else: max_gain_node = None

        return max_gain_node, overall_max_gain
    
    def optimal_partition_circuit(self):
        partition1, partition2 = {}, {}
        target_area = self.ratio * self.W
        sorted_gates = sorted(self.circuit_gate_areas.items(), key=lambda x: x[1], reverse = True) 
        for gate, area in sorted_gates:
            if sum(partition1.values()) + area <= target_area:
                partition1[gate] = area
            else:
                partition2[gate] = area
        return partition1, partition2

    def get_optimal_moves(self, circuit_area):
        optimal_moves = []

        area_sums1 = self.get_partition_areasums(self.bucket_gains1)
        area_sums2 = self.get_partition_areasums(self.bucket_gains2)
        
        for gate in circuit_area.keys():
            node = self.vertex[gate]
            if node.bucket_side == self.bucket_gains1:
                source_partiton_area = area_sums1 - node.area
                dest_partition_area = area_sums2 + node.area
            else: # if node.bucket_side == self.bucket_gains2
                source_partiton_area = area_sums2 - node.area
                dest_partition_area = area_sums1 + node.area

            #BALANCE CRITERION --> rW - k * s_max <= |Partition area| <= rW + k * s_max
            source_criterion = (self.ratio * self.W) - (self.k * self.s_max) <= source_partiton_area <= (self.ratio * self.W) + (self.k * self.s_max)
            dest_criterion = (self.ratio * self.W) - (self.k * self.s_max) <= dest_partition_area <= (self.ratio * self.W) + (self.k * self.s_max)
            if source_criterion or dest_criterion:
                optimal_moves.append((gate, node.gain))
        optimal_moves.sort(key=lambda x: x[1], reverse=True)
        return optimal_moves

    def partition_circuit(self):
        circuit_nodes = list(self.circuit_connections_out.keys())
        random.shuffle(circuit_nodes)
        partition = len(circuit_nodes) // 2

        partition1 = circuit_nodes[:partition]
        partition2 = circuit_nodes[partition:] 
        return partition1, partition2
    
    def calculate_initial_gain(self, gate):
        external_sum = 0
        internal_sum = 0

        if gate in self.partition1:
            current_partition = self.partition1
        else:
            current_partition = self.partition2

        #output connections
        for next_gate in self.circuit_connections_out[gate]:
            if next_gate in current_partition:
                internal_sum += 1
            else:
                external_sum += 1
        
        #input connnections
        for prev_gate in self.circuit_connections_in[gate]:
            if prev_gate in current_partition:
                internal_sum += 1
            else:
                external_sum += 1
        
        #calculate gain
        gain = external_sum - internal_sum

        return gain


    def calculate_gain(self, gate):
        external_sum = 0
        internal_sum = 0

        current_partition = self.vertex[gate].bucket_side

        #output connections
        for next_gate in self.circuit_connections_out[gate]:
            next_gate_side = self.vertex[next_gate].bucket_side
            if next_gate_side == current_partition:
                internal_sum += 1
            else:
                external_sum += 1
        
        #input connnections
        for prev_gate in self.circuit_connections_in[gate]:
            prev_gate_side = self.vertex[prev_gate].bucket_side
            if prev_gate_side == current_partition:
                internal_sum += 1
            else:
                external_sum += 1
                
        #calculate gain
        gain = external_sum - internal_sum

        return gain
        
    def initialize_buckets(self, partition, bucket):
        for gate, area in partition.items():
            current_gate = gate_dlinkedList(gate, bucket, area)
            self.vertex[gate] = current_gate

            gain = self.calculate_initial_gain(gate)
            current_gate.gain = gain
            
            if gain in bucket.keys():
                bucket[gain] = bucket[gain].set_next(current_gate)
                bucket[gain].next = None
            else:
                bucket[gain] = current_gate #gate must be doubly linked list OOC
                bucket[gain].prev = None
                bucket[gain].next = None

            if bucket == self.bucket_gains1:
                self.bucket_count1 += 1
            else:
                self.bucket_count2 += 1
        return bucket

# %%
# test 5 iteration
def main():
    circuit_folder_path = "test_simple"
    fm = FM_algo(circuit_folder_path)
if __name__ == "__main__":
    main()
# Out:
# input connections {'p1': [], 'a0': ['p1'], 'a1': ['p1'], 'a2': ['a0', 'a1'], 'a3': ['a0', 'a1'], 'p2': ['a2'], 'p3': ['a3']}
# output connections {'p1': ['a0', 'a1'], 'a0': ['a2', 'a3'], 'a1': ['a2', 'a3'], 'a2': ['p2'], 'a3': ['p3'], 'p2': [], 'p3': []}
# parition1  {'a2': 4, 'a0': 1, 'p1': 0, 'p2': 0, 'p3': 0}
# parition2  {'a1': 3, 'a3': 2}
# Number of Iterations: 1
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 2
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 3
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 4
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 5
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Initial Cut Size: 4
# Fiduccia-Mattheyses Algorithm Complete!
# Runtime: 0.0015118122100830078 seconds
# Best Cut Size: 2
# Total number of iterations: 5
# Improvement percentage: 50.0%
# Number of Gates in Bucket 1: 2
# Number of Gates in Bucket 2: 5

# %%
def main():
    circuit_folder_path = "test_simple"
    fm = FM_algo(circuit_folder_path)
if __name__ == "__main__":
    main()
# Out:
# input connections {'p1': [], 'a0': ['p1'], 'a1': ['p1'], 'a2': ['a0', 'a1'], 'a3': ['a0', 'a1'], 'p2': ['a2'], 'p3': ['a3']}
# output connections {'p1': ['a0', 'a1'], 'a0': ['a2', 'a3'], 'a1': ['a2', 'a3'], 'a2': ['p2'], 'a3': ['p3'], 'p2': [], 'p3': []}
# parition1  {'a2': 4, 'a0': 1, 'p1': 0, 'p2': 0, 'p3': 0}
# parition2  {'a1': 3, 'a3': 2}
# Number of Iterations: 1
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 2
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 3
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 4
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Number of Iterations: 5
# FM progress: 1 / 7
# FM progress: 2 / 7
# FM progress: 3 / 7
# FM progress: 4 / 7
# FM progress: 5 / 7
# Initial Cut Size: 4
# Fiduccia-Mattheyses Algorithm Complete!
# Runtime: 0.002000093460083008 seconds
# Best Cut Size: 2
# Total number of iterations: 5
# Improvement percentage: 50.0%
# Number of Gates in Bucket 1: 2
# Number of Gates in Bucket 2: 5

# %%
def main():
    circuit_folder_path = "test1"
    fm = FM_algo(circuit_folder_path)
if __name__ == "__main__":
    main()
# Out:
# input connections {'p198': [], 'a8117': ['p198', 'a7337', 'a9851', 'a7337', 'a9205', 'a9205', 'a9205', 'a9205', 'a5346'], 'a3044': ['a10425', 'a10425', 'a10425', 'a10425', 'a5154', 'a5154', 'a11352', 'a11352', 'a11352', 'a11352', 'a10425'], 'p98': ['a3044'], 'a3767': ['a6413', 'a6413', 'a6413', 'a6413', 'a3728', 'a5346'], 'p245': ['a3767'], 'a4992': ['a3981', 'a3981', 'a10461', 'a10461', 'a10461', 'a10461', 'a10425'], 'p231': ['a4992'], 'a6837': ['a9205', 'a9205', 'a9205', 'a9205', 'a12327', 'a6871', 'a12327', 'a11654', 'a11654', 'a11654', 'a11654', 'a8118'], 'p9': ['a6837'], 'a9877': ['a3418'], 'p52': ['a9877'], 'p146': [], 'a2553': ['p146', 'a9415', 'a2559', 'a5731'], 'a3427': ['a11677', 'a3767', 'a11677', 'a3767', 'a11677', 'a3767', 'a11677', 'a3767', 'a8793', 'a878', 'a8793', 'a5346'], 'p18': ['a3427'], 'a7784': ['a10972', 'a10972', 'a10972', 'a10972', 'a8321', 'a3881'], 'p17': ['a7784'], 'a6569': ['a3186'], 'p101': ['a6569'], 'p22': [], 'a459': ['p22', 'a2553', 'a2553', 'a2553', 'a2553', 'a5955', 'a4115', 'a5955', 'a5731'], 'a10513': ['a2797'], 'p157': ['a10513'], 'p190': [], 'a5346': ['p190', 'a8438', 'a3849', 'a8438', 'a3849', 'a8438', 'a3849', 'a8438', 'a3849', 'a5276'], 'a8418': ['a6443', 'a6443', 'a6443', 'a6443', 'a8551'], 'p54': ['a8418'], 'a11211': ['a10399', 'a10399', 'a5731'], 'p84': ['a11211'], 'a6816': ['a6117', 'a7398', 'a11574'], 'p171': ['a6816'], 'p13': [], 'a5844': ['p13', 'a4874'], 'a7943': [], 'p24': ['a7943'], 'p180': [], 'a5131': ['p180'], 'a5139': [], 'p46': ['a5139'], 'p45': [], 'a2960': ['p45', 'a977', 'a977', 'a977', 'a977', 'a9825', 'a6753'], 'p134': [], 'a5011': ['p134', 'a8418', 'a8418', 'a8418', 'a8418', 'a3914', 'a2493', 'a3914', 'a5346'], 'a3881': ['a2239', 'a6968', 'a2239', 'a6968', 'a2239', 'a6968', 'a2239', 'a6968', 'a9331', 'a9331'], 'p127': ['a3881'], 'a12097': ['a11211', 'a11211', 'a11211', 'a11211', 'a687', 'a687', 'a687', 'a687', 'a5731'], 'p130': ['a12097'], 'a10682': ['a1264'], 'p172': ['a10682'], 'a8618': ['a6753'], 'p8': ['a8618'], 'a2551': ['a6753'], 'p95': ['a2551'], 'p32': [], 'a9403': ['p32', 'a980', 'a2491', 'a2491', 'a6753'], 'p93': [], 'a3821': ['p93', 'a12170', 'a10884', 'a1317', 'a7943', 'a901', 'a901', 'a901', 'a5578'], 'a1569': ['a8618', 'a6885', 'a8618', 'a6885', 'a8618', 'a6885', 'a8618', 'a6885', 'a5695', 'a1299', 'a1299', 'a6753'], 'p193': ['a1569'], 'p107': [], 'a11468': ['p107', 'a11612', 'a869'], 'a2239': ['a8118'], 'p108': ['a2239'], 'p68': [], 'a8556': ['p68', 'a6034', 'a6753'], 'p16': [], 'a22': ['p16', 'a8556', 'a8556', 'a8556', 'a8556', 'a4172', 'a5965', 'a5965', 'a6753'], 'a6885': ['a4321', 'a5369', 'a5369', 'a5369', 'a5369', 'a6753'], 'p153': ['a6885'], 'p158': [], 'a4433': ['p158', 'a8556', 'a8556', 'a8556', 'a8556', 'a6752', 'a6752', 'a6753'], 'a2911': ['a11960', 'a2960', 'a2960', 'a2960', 'a2960', 'a5731'], 'p225': ['a2911'], 'a12246': ['a8982', 'a698'], 'p38': ['a12246'], 'p236': [], 'a10779': ['p236', 'a22', 'a11347', 'a22', 'a11347', 'a22', 'a11347', 'a22', 'a11347', 'a11393', 'a6753'], 'a687': ['a6753', 'a4157', 'a19'], 'p142': ['a687'], 'a5385': ['a11677', 'a11677', 'a11677', 'a11677', 'a4337', 'a4337', 'a3881'], 'p41': ['a5385'], 'p129': [], 'a7381': ['p129', 'a11211', 'a11211', 'a11211', 'a11211', 'a7332', 'a5731'], 'a8287': ['a7576', 'a7576', 'a7576', 'a7576', 'a10780'], 'p81': ['a8287'], 'a2835': [], 'p49': ['a2835'], 'p71': [], 'a1679': ['p71', 'a12226', 'a10822', 'a12226', 'a6996', 'a6996', 'a6996', 'a6996', 'a6753'], 'p162': [], 'a9032': ['p162', 'a9368', 'a9368', 'a9368', 'a9368', 'a12409', 'a12409', 'a12409', 'a12409', 'a11516', 'a11516', 'a6124'], 'a6455': ['a6544', 'a8491', 'a8491', 'a3195'], 'p39': ['a6455'], 'p137': [], 'a12110': ['p137', 'a10016', 'a7965', 'a10016', 'a7965', 'a10016', 'a7965', 'a10016', 'a7965', 'a6376', 'a1990', 'a1990', 'a3195'], 'p87': [], 'a2546': ['p87', 'a6373', 'a6373', 'a6373', 'a6373', 'a4861', 'a4861', 'a3195'], 'p136': [], 'a8855': ['p136', 'a537', 'a537', 'a537', 'a537', 'a3152', 'a11243', 'a11243', 'a319 ...
# output connections {'p198': ['a8117'], 'a8117': ['a4673', 'a4673', 'a4673', 'a4673'], 'a3044': ['p98', 'a3304'], 'p98': [], 'a3767': ['p245', 'a3427', 'a3427', 'a3427', 'a3427', 'a8042', 'a8042'], 'p245': [], 'a4992': ['p231', 'a8181', 'a8181', 'a8181', 'a8181', 'a6695'], 'p231': [], 'a6837': ['p9'], 'p9': [], 'a9877': ['p52'], 'p52': [], 'p146': ['a2553'], 'a2553': ['a459', 'a459', 'a5686', 'a459', 'a11788', 'a459', 'a7753', 'a5389', 'a5389'], 'a3427': ['p18'], 'p18': [], 'a7784': ['p17', 'a3849', 'a3849', 'a3849', 'a3849', 'a11781', 'a11781'], 'p17': [], 'a6569': ['p101'], 'p101': [], 'p22': ['a459'], 'a459': ['a6800', 'a6800', 'a6800', 'a6800'], 'a10513': ['p157'], 'p157': [], 'p190': ['a5346'], 'a5346': ['a2479', 'a2479', 'a7267', 'a3427', 'a8774', 'a3767', 'a7891', 'a8117', 'a5011'], 'a8418': ['p54', 'a5011', 'a5011', 'a5011', 'a5011', 'a5752', 'a5752', 'a11435', 'a3136'], 'p54': [], 'a11211': ['p84', 'a12097', 'a7381', 'a12097', 'a7381', 'a12097', 'a7381', 'a12097', 'a7381', 'a569'], 'p84': [], 'a6816': ['p171', 'a9122'], 'p171': [], 'p13': ['a5844'], 'a5844': [], 'a7943': ['p24', 'p246', 'a12324', 'a3821', 'a901'], 'p24': [], 'p180': ['a5131'], 'a5131': ['a11522'], 'a5139': ['p46', 'a11946', 'a11992', 'a777'], 'p46': [], 'p45': ['a2960'], 'a2960': ['a7503', 'a7503', 'a2911', 'a2911', 'a2911', 'a2911'], 'p134': ['a5011'], 'a5011': ['a10783', 'a10783', 'a10783', 'a10783'], 'a3881': ['p127', 'a7113', 'a9277', 'a7784', 'a5385', 'a11677', 'a4378'], 'p127': [], 'a12097': ['p130', 'a1977', 'a1352', 'a1977'], 'p130': [], 'a10682': ['p172'], 'p172': [], 'a8618': ['p8', 'a9045', 'a1569', 'a9928', 'a1569', 'a7477', 'a1569', 'a11513', 'a1569', 'a10693', 'a11118', 'a11118'], 'p8': [], 'a2551': ['p95', 'a11688', 'a11688', 'a11688', 'a11688', 'a9441', 'a7365', 'a7365', 'a7671', 'a7671', 'a7671', 'a7671'], 'p95': [], 'p32': ['a9403'], 'a9403': ['a9686', 'a2451', 'a9686', 'a2451', 'a9686', 'a2451', 'a9686', 'a2451'], 'p93': ['a3821'], 'a3821': ['a415', 'a2119', 'a1628', 'a1628'], 'a1569': ['p193'], 'p193': [], 'p107': ['a11468'], 'a11468': ['a5455', 'a5455', 'a5455', 'a5455', 'a6796', 'a6796', 'a5755', 'a5755', 'a5755', 'a5755'], 'a2239': ['p108', 'a6443', 'a3881', 'a6443', 'a3881', 'a6443', 'a3881', 'a6443', 'a3881', 'a3712', 'a1044', 'a3712'], 'p108': [], 'p68': ['a8556'], 'a8556': ['a22', 'a4433', 'a22', 'a4433', 'a22', 'a4433', 'a22', 'a4433', 'a60', 'a60'], 'p16': ['a22'], 'a22': ['a10779', 'a10779', 'a10779', 'a10779'], 'a6885': ['p153', 'a1569', 'a1569', 'a1569', 'a1569', 'a4880', 'a4880'], 'p153': [], 'p158': ['a4433'], 'a4433': ['a11532', 'a2451', 'a2451', 'a2451', 'a2451'], 'a2911': ['p225', 'a6800', 'a6800', 'a6800', 'a6800', 'a6652', 'a6652'], 'p225': [], 'a12246': ['p38', 'a3411', 'a3411', 'a3641', 'a3641', 'a3641', 'a3641', 'a8514', 'a8514', 'a8514', 'a8514'], 'p38': [], 'p236': ['a10779'], 'a10779': ['a9028', 'a9028'], 'a687': ['p142', 'a4757', 'a10590', 'a4757', 'a12097', 'a12097', 'a12097', 'a12097', 'a4753', 'a4719'], 'p142': [], 'a5385': ['p41', 'a10972', 'a10972', 'a10972', 'a10972', 'a8639'], 'p41': [], 'p129': ['a7381'], 'a7381': ['a610', 'a610', 'a610', 'a610', 'a8167', 'a8167'], 'a8287': ['p81', 'a4983', 'a559', 'a559'], 'p81': [], 'a2835': ['p49', 'a5515', 'a12403', 'a7154', 'a1667', 'a159'], 'p49': [], 'p71': ['a1679'], 'a1679': ['a610', 'a610', 'a610', 'a610'], 'p162': ['a9032'], 'a9032': ['a9778'], 'a6455': ['p39', 'a9838', 'a9838', 'a9838', 'a9838', 'a380', 'a380', 'a380', 'a380'], 'p39': [], 'p137': ['a12110'], 'a12110': [], 'p87': ['a2546'], 'a2546': ['a9943', 'a9943', 'a9943', 'a9943', 'a4169'], 'p136': ['a8855'], 'a8855': ['a10229', 'a10229', 'a10229', 'a10229'], 'p64': ['a9972'], 'a9972': ['a1469'], 'a11677': ['p204', 'a3427', 'a5385', 'a3427', 'a5385', 'a3427', 'a5385', 'a3427', 'a5385', 'a2611'], 'p204': [], 'p199': ['a11347'], 'a11347': ['a10779', 'a10779', 'a10779', 'a10779', 'a3759', 'a3759'], 'p37': ['a2286'], 'a2286': ['a6112', 'a6112', 'a6112', 'a6112'], 'a5369': ['p184', 'a3440', 'a2765', 'a344 ...
# parition1  {'a12324': 269568, 'a7943': 16128, 'a5865': 15936, 'a22': 8064, 'a23': 8064, 'a26': 8064, 'a152': 8064, 'a175': 8064, 'a263': 8064, 'a289': 8064, 'a338': 8064, 'a380': 8064, 'a459': 8064, 'a503': 8064, 'a537': 8064, 'a592': 8064, 'a610': 8064, 'a687': 8064, 'a698': 8064, 'a901': 8064, 'a962': 8064, 'a977': 8064, 'a1086': 8064, 'a1125': 8064, 'a1139': 8064, 'a1149': 8064, 'a1176': 8064, 'a1427': 8064, 'a1569': 8064, 'a1679': 8064, 'a1692': 8064, 'a1730': 8064, 'a1829': 8064, 'a1844': 8064, 'a1934': 8064, 'a1989': 8064, 'a2167': 8064, 'a2239': 8064, 'a2240': 8064, 'a2286': 8064, 'a2347': 8064, 'a2451': 8064, 'a2524': 8064, 'a2546': 8064, 'a2551': 8064, 'a2553': 8064, 'a2650': 8064, 'a2657': 8064, 'a2674': 8064, 'a2684': 8064, 'a2777': 8064, 'a2812': 8064, 'a2835': 8064, 'a2883': 8064, 'a2911': 8064, 'a2960': 8064, 'a2973': 8064, 'a3044': 8064, 'a3148': 8064, 'a3169': 8064, 'a3209': 8064, 'a3248': 8064, 'a3401': 8064, 'a3427': 8064, 'a3641': 8064, 'a3683': 8064, 'a3747': 8064, 'a3767': 8064, 'a3778': 8064, 'a3821': 8064, 'a3849': 8064, 'a3881': 8064, 'a4041': 8064, 'a4127': 8064, 'a4262': 8064, 'a4348': 8064, 'a4377': 8064, 'a4397': 8064, 'a4420': 8064, 'a4431': 8064, 'a4433': 8064, 'a4435': 8064, 'a4491': 8064, 'a4496': 8064, 'a4620': 8064, 'a4646': 8064, 'a4673': 8064, 'a4682': 8064, 'a4683': 8064, 'a4697': 8064, 'a4731': 8064, 'a4739': 8064, 'a4822': 8064, 'a4847': 8064, 'a4981': 8064, 'a4992': 8064, 'a5011': 8064, 'a5046': 8064, 'a5131': 8064, 'a5139': 8064, 'a5214': 8064, 'a5275': 8064, 'a5295': 8064, 'a5346': 8064, 'a5369': 8064, 'a5385': 8064, 'a5455': 8064, 'a5567': 8064, 'a5731': 8064, 'a5755': 8064, 'a5835': 8064, 'a5844': 8064, 'a5893': 8064, 'a5916': 8064, 'a5987': 8064, 'a6112': 8064, 'a6148': 8064, 'a6173': 8064, 'a6243': 8064, 'a6295': 8064, 'a6324': 8064, 'a6373': 8064, 'a6382': 8064, 'a6413': 8064, 'a6443': 8064, 'a6455': 8064, 'a6568': 8064, 'a6569': 8064, 'a6637': 8064, 'a6735': 8064, 'a6800': 8064, 'a6816': 8064, 'a6822': 8064, 'a6837': 8064, 'a6885': 8064, 'a6941': 8064, 'a6968': 8064, 'a6991': 8064, 'a6996': 8064, 'a7128': 8064, 'a7280': 8064, 'a7381': 8064, 'a7419': 8064, 'a7576': 8064, 'a7586': 8064, 'a7614': 8064, 'a7647': 8064, 'a7671': 8064, 'a7737': 8064, 'a7784': 8064, 'a7823': 8064, 'a7873': 8064, 'a7891': 8064, 'a7965': 8064, 'a7995': 8064, 'a8018': 8064, 'a8117': 8064, 'a8156': 8064, 'a8181': 8064, 'a8229': 8064, 'a8244': 8064, 'a8287': 8064, 'a8304': 8064, 'a8418': 8064, 'a8419': 8064, 'a8438': 8064, 'a8514': 8064, 'a8556': 8064, 'a8600': 8064, 'a8618': 8064, 'a8774': 8064, 'a8855': 8064, 'a8867': 8064, 'a9032': 8064, 'a9149': 8064, 'a9163': 8064, 'a9167': 8064, 'a9174': 8064, 'a9205': 8064, 'a9211': 8064, 'a9233': 8064, 'a9263': 8064, 'a9327': 8064, 'a9368': 8064, 'a9383': 8064, 'a9403': 8064, 'a9426': 8064, 'a9578': 8064, 'a9653': 8064, 'a9668': 8064, 'a9686': 8064, 'a9736': 8064, 'a9784': 8064, 'a9838': 8064, 'a9854': 8064, 'a9877': 8064, 'a9943': 8064, 'a9972': 8064, 'a10012': 8064, 'a10016': 8064, 'a10028': 8064, 'a10191': 8064, 'a10195': 8064, 'a10208': 8064, 'a10229': 8064, 'a10366': 8064, 'a10425': 8064, 'a10461': 8064, 'a10513': 8064, 'a10575': 8064, 'a10622': 8064, 'a10682': 8064, 'a10779': 8064, 'a10783': 8064, 'a10872': 8064, 'a10972': 8064, 'a10974': 8064, 'a11094': 8064, 'a11133': 8064, 'a11194': 8064, 'a11201': 8064, 'a11211': 8064, 'a11251': 8064, 'a11286': 8064, 'a11328': 8064, 'a11347': 8064, 'a11352': 8064, 'a1190': 736, 'a1766': 736, 'a4242': 736, 'a10': 672, 'a60': 672, 'a104': 672, 'a206': 672, 'a326': 672, 'a353': 672, 'a381': 672, 'a2': 128, 'p1': 0, 'p2': 0, 'p3': 0, 'p4': 0, 'p5': 0, 'p6': 0, 'p7': 0, 'p8': 0, 'p9': 0, 'p10': 0, 'p11': 0, 'p12': 0, 'p13': 0, 'p14': 0, 'p15': 0, 'p16': 0, 'p17': 0, 'p18': 0, 'p19': 0, 'p20': 0, 'p21': 0, 'p22': 0, 'p23': 0, 'p24': 0, 'p25': 0, 'p26': 0, 'p27': 0, 'p28': 0, 'p29': 0, 'p30': 0, 'p31': 0, 'p32': 0, 'p33': 0, 'p34': 0, 'p35': 0, 'p36': 0, 'p37': 0, 'p38': 0, 'p39': 0, 'p40': 0, 'p41': 0, 'p42': 0, 'p43': 0, 'p44': 0 ...
# parition2  {'a11421': 8064, 'a11435': 8064, 'a11468': 8064, 'a11530': 8064, 'a11654': 8064, 'a11677': 8064, 'a11688': 8064, 'a11729': 8064, 'a11806': 8064, 'a11874': 8064, 'a11928': 8064, 'a11935': 8064, 'a12097': 8064, 'a12110': 8064, 'a12156': 8064, 'a12162': 8064, 'a12246': 8064, 'a12409': 8064, 'a12474': 8064, 'a467': 672, 'a481': 672, 'a516': 672, 'a559': 672, 'a640': 672, 'a1024': 672, 'a1066': 672, 'a1174': 672, 'a1233': 672, 'a1270': 672, 'a1299': 672, 'a1438': 672, 'a1489': 672, 'a1506': 672, 'a1628': 672, 'a1687': 672, 'a1718': 672, 'a1736': 672, 'a1755': 672, 'a1764': 672, 'a1790': 672, 'a1888': 672, 'a1917': 672, 'a1957': 672, 'a1977': 672, 'a1990': 672, 'a2076': 672, 'a2110': 672, 'a2116': 672, 'a2169': 672, 'a2211': 672, 'a2252': 672, 'a2361': 672, 'a2479': 672, 'a2491': 672, 'a2621': 672, 'a2671': 672, 'a2787': 672, 'a2805': 672, 'a2910': 672, 'a2930': 672, 'a2972': 672, 'a2981': 672, 'a3007': 672, 'a3064': 672, 'a3297': 672, 'a3328': 672, 'a3371': 672, 'a3380': 672, 'a3405': 672, 'a3411': 672, 'a3432': 672, 'a3440': 672, 'a3471': 672, 'a3601': 672, 'a3642': 672, 'a3668': 672, 'a3712': 672, 'a3759': 672, 'a3828': 672, 'a3855': 672, 'a3914': 672, 'a3981': 672, 'a4022': 672, 'a4036': 672, 'a4103': 672, 'a4309': 672, 'a4337': 672, 'a4412': 672, 'a4428': 672, 'a4487': 672, 'a4497': 672, 'a4610': 672, 'a4757': 672, 'a4766': 672, 'a4858': 672, 'a4861': 672, 'a4880': 672, 'a4918': 672, 'a4922': 672, 'a4938': 672, 'a5007': 672, 'a5031': 672, 'a5042': 672, 'a5056': 672, 'a5154': 672, 'a5184': 672, 'a5230': 672, 'a5322': 672, 'a5334': 672, 'a5353': 672, 'a5389': 672, 'a5752': 672, 'a5759': 672, 'a5862': 672, 'a5922': 672, 'a5934': 672, 'a5949': 672, 'a5955': 672, 'a5965': 672, 'a6053': 672, 'a6121': 672, 'a6167': 672, 'a6176': 672, 'a6253': 672, 'a6418': 672, 'a6610': 672, 'a6652': 672, 'a6752': 672, 'a6772': 672, 'a6796': 672, 'a6839': 672, 'a6884': 672, 'a6914': 672, 'a6958': 672, 'a6980': 672, 'a6999': 672, 'a7004': 672, 'a7052': 672, 'a7057': 672, 'a7166': 672, 'a7253': 672, 'a7337': 672, 'a7365': 672, 'a7421': 672, 'a7501': 672, 'a7503': 672, 'a7546': 672, 'a7709': 672, 'a7712': 672, 'a7777': 672, 'a7945': 672, 'a7963': 672, 'a8042': 672, 'a8131': 672, 'a8163': 672, 'a8167': 672, 'a8178': 672, 'a8475': 672, 'a8491': 672, 'a8500': 672, 'a8563': 672, 'a8637': 672, 'a8703': 672, 'a8793': 672, 'a8802': 672, 'a8887': 672, 'a8949': 672, 'a9028': 672, 'a9062': 672, 'a9063': 672, 'a9119': 672, 'a9134': 672, 'a9151': 672, 'a9251': 672, 'a9331': 672, 'a9379': 672, 'a9506': 672, 'a9511': 672, 'a9573': 672, 'a9605': 672, 'a9727': 672, 'a9770': 672, 'a10071': 672, 'a10096': 672, 'a10223': 672, 'a10225': 672, 'a10262': 672, 'a10353': 672, 'a10386': 672, 'a10396': 672, 'a10399': 672, 'a10463': 672, 'a10511': 672, 'a10544': 672, 'a10657': 672, 'a10703': 672, 'a10711': 672, 'a10714': 672, 'a10756': 672, 'a10791': 672, 'a10824': 672, 'a10916': 672, 'a10934': 672, 'a11046': 672, 'a11072': 672, 'a11118': 672, 'a11191': 672, 'a11208': 672, 'a11243': 672, 'a11410': 672, 'a11463': 672, 'a11516': 672, 'a11563': 672, 'a11592': 672, 'a11689': 672, 'a11718': 672, 'a11738': 672, 'a11781': 672, 'a11815': 672, 'a11876': 672, 'a11964': 672, 'a11994': 672, 'a12038': 672, 'a12090': 672, 'a12131': 672, 'a12205': 672, 'a12226': 672, 'a12327': 672, 'a12354': 672, 'a12367': 672, 'a12418': 672, 'a12460': 672, 'a12461': 672, 'a918': 544, 'a1969': 544, 'a4455': 544, 'a4538': 544, 'a5815': 544, 'a9131': 544, 'a840': 480, 'a1410': 480, 'a1505': 480, 'a2665': 480, 'a2964': 480, 'a3096': 480, 'a3218': 480, 'a4200': 480, 'a5551': 480, 'a5737': 480, 'a6084': 480, 'a6217': 480, 'a6254': 480, 'a6699': 480, 'a6806': 480, 'a6836': 480, 'a6853': 480, 'a7018': 480, 'a7552': 480, 'a7799': 480, 'a7844': 480, 'a7845': 480, 'a9764': 480, 'a10094': 480, 'a10264': 480, 'a10776': 480, 'a10866': 480, 'a11066': 480, 'a11536': 480, 'a12465': 480, 'a231': 448, 'a257': 448, 'a408': 448, 'a576': 448, 'a603': 448, 'a1020': 448, 'a1118': 448, 'a1131': 448, 'a1784': 448, 'a1810': 448 ...
# Number of Iterations: 1
# FM progress: 1 / 12752
# FM progress: 2 / 12752
# FM progress: 3 / 12752
# FM progress: 4 / 12752
# FM progress: 5 / 12752
# FM progress: 6 / 12752
# FM progress: 7 / 12752
# FM progress: 8 / 12752
# FM progress: 9 / 12752
# FM progress: 10 / 12752
# FM progress: 11 / 12752
# FM progress: 12 / 12752
# FM progress: 13 / 12752
# FM progress: 14 / 12752
# FM progress: 15 / 12752
# FM progress: 16 / 12752
# FM progress: 17 / 12752
# FM progress: 18 / 12752
# FM progress: 19 / 12752
# FM progress: 20 / 12752
# FM progress: 21 / 12752
# FM progress: 22 / 12752
# FM progress: 23 / 12752
# FM progress: 24 / 12752
# FM progress: 25 / 12752
# FM progress: 26 / 12752
# FM progress: 27 / 12752
# FM progress: 28 / 12752
# FM progress: 29 / 12752
# FM progress: 30 / 12752
# FM progress: 31 / 12752
# FM progress: 32 / 12752
# FM progress: 33 / 12752
# FM progress: 34 / 12752
# FM progress: 35 / 12752
# FM progress: 36 / 12752
# FM progress: 37 / 12752
# FM progress: 38 / 12752
# FM progress: 39 / 12752
# FM progress: 40 / 12752
# FM progress: 41 / 12752
# FM progress: 42 / 12752
# FM progress: 43 / 12752
# FM progress: 44 / 12752
# FM progress: 45 / 12752
# FM progress: 46 / 12752
# FM progress: 47 / 12752
# FM progress: 48 / 12752
# FM progress: 49 / 12752
# FM progress: 50 / 12752
# FM progress: 51 / 12752
# FM progress: 52 / 12752
# FM progress: 53 / 12752
# FM progress: 54 / 12752
# FM progress: 55 / 12752
# FM progress: 56 / 12752
# FM progress: 57 / 12752
# FM progress: 58 / 12752
# FM progress: 59 / 12752
# FM progress: 60 / 12752
# FM progress: 61 / 12752
# FM progress: 62 / 12752
# FM progress: 63 / 12752
# FM progress: 64 / 12752
# FM progress: 65 / 12752
# FM progress: 66 / 12752
# FM progress: 67 / 12752
# FM progress: 68 / 12752
# FM progress: 69 / 12752
# FM progress: 70 / 12752
# FM progress: 71 / 12752
# FM progress: 72 / 12752
# FM progress: 73 / 12752
# FM progress: 74 / 12752
# FM progress: 75 / 12752
# FM progress: 76 / 12752
# FM progress: 77 / 12752
# FM progress: 78 / 12752
# FM progress: 79 / 12752
# FM progress: 80 / 12752
# FM progress: 81 / 12752
# FM progress: 82 / 12752
# FM progress: 83 / 12752
# FM progress: 84 / 12752
# FM progress: 85 / 12752
# FM progress: 86 / 12752
# FM progress: 87 / 12752
# FM progress: 88 / 12752
# FM progress: 89 / 12752
# FM progress: 90 / 12752
# FM progress: 91 / 12752
# FM progress: 92 / 12752
# FM progress: 93 / 12752
# FM progress: 94 / 12752
# FM progress: 95 / 12752
# FM progress: 96 / 12752
# FM progress: 97 / 12752
# FM progress: 98 / 12752
# FM progress: 99 / 12752
# FM progress: 100 / 12752
# FM progress: 101 / 12752
# FM progress: 102 / 12752
# FM progress: 103 / 12752
# FM progress: 104 / 12752
# FM progress: 105 / 12752
# FM progress: 106 / 12752
# FM progress: 107 / 12752
# FM progress: 108 / 12752
# FM progress: 109 / 12752
# FM progress: 110 / 12752
# FM progress: 111 / 12752
# FM progress: 112 / 12752
# FM progress: 113 / 12752
# FM progress: 114 / 12752
# FM progress: 115 / 12752
# FM progress: 116 / 12752
# FM progress: 117 / 12752
# FM progress: 118 / 12752
# FM progress: 119 / 12752
# FM progress: 120 / 12752
# FM progress: 121 / 12752
# FM progress: 122 / 12752
# FM progress: 123 / 12752
# FM progress: 124 / 12752
# FM progress: 125 / 12752
# FM progress: 126 / 12752
# FM progress: 127 / 12752
# FM progress: 128 / 12752
# FM progress: 129 / 12752
# FM progress: 130 / 12752
# FM progress: 131 / 12752
# FM progress: 132 / 12752
# FM progress: 133 / 12752
# FM progress: 134 / 12752
# FM progress: 135 / 12752
# FM progress: 136 / 12752
# FM progress: 137 / 12752
# FM progress: 138 / 12752
# FM progress: 139 / 12752
# FM progress: 140 / 12752
# FM progress: 141 / 12752
# FM progress: 142 / 12752
# FM progress: 143 / 12752
# FM progress: 144 / 12752
# FM progress: 145 / 12752
# FM progress: 146 / 12752
# FM progress: 147 / 12752
# FM progress: 148 / 12752
# FM progress: 149 / 12752
# FM progress: 150 / 12752
# FM progress: 151 / 12752
# FM progress: 152 / 12752
# FM progress: 153 / 12752
# FM progress: 154 / 12752
# FM progress: 155 / 12752
# FM progress: 156 / 12752
# FM progress: 157 / 12752
# FM progress: 158 / 12752
# FM progress: 159 / 12752
# FM progress: 160 / 12752
# FM progress: 161 / 12752
# FM progress: 162 / 12752
# FM progress: 163 / 12752
# FM progress: 164 / 12752
# FM progress: 165 / 12752
# FM progress: 166 / 12752
# FM progress: 167 / 12752
# FM progress: 168 / 12752
# FM progress: 169 / 12752
# FM progress: 170 / 12752
# FM progress: 171 / 12752
# FM progress: 172 / 12752
# FM progress: 173 / 12752
# FM progress: 174 / 12752
# FM progress: 175 / 12752
# FM progress: 176 / 12752
# FM progress: 177 / 12752
# FM progress: 178 / 12752
# FM progress: 179 / 12752
# FM progress: 180 / 12752
# FM progress: 181 / 12752
# FM progress: 182 / 12752
# FM progress: 183 / 12752
# FM progress: 184 / 12752
# FM progress: 185 / 12752
# FM progress: 186 / 12752
# FM progress: 187 / 12752
# FM progress: 188 / 12752
# FM progress: 189 / 12752
# FM progress: 190 / 12752
# FM progress: 191 / 12752
# FM progress: 192 / 12752
# FM progress: 193 / 12752
# FM progress: 194 / 12752
# FM progress: 195 / 12752
# FM progress: 196 / 12752
# FM progress: 197 / 12752
# FM progress: 198 / 12752
# FM progress: 199 / 12752
# FM progress: 200 / 12752
# FM progress: 201 / 12752
# FM progress: 202 / 12752
# FM progress: 203 / 12752
# FM progress: 204 / 12752
# FM progress: 205 / 12752
# FM progress: 206 / 12752
# FM progress: 207 / 12752
# FM progress: 208 / 12752
# FM progress: 209 / 12752
# FM progress: 210 / 12752
# FM progress: 211 / 12752
# FM progress: 212 / 12752
# FM progress: 213 / 12752
# FM progress: 214 / 12752
# FM progress: 215 / 12752
# FM progress: 216 / 12752
# FM progress: 217 / 12752
# FM progress: 218 / 12752
# FM progress: 219 / 12752
# FM progress: 220 / 12752
# FM progress: 221 / 12752
# FM progress: 222 / 12752
# FM progress: 223 / 12752
# FM progress: 224 / 12752
# FM progress: 225 / 12752
# FM progress: 226 / 12752
# FM progress: 227 / 12752
# FM progress: 228 / 12752
# FM progress: 229 / 12752
# FM progress: 230 / 12752
# FM progress: 231 / 12752
# FM progress: 232 / 12752
# FM progress: 233 / 12752
# FM progress: 234 / 12752
# FM progress: 235 / 12752
# FM progress: 236 / 12752
# FM progress: 237 / 12752
# FM progress: 238 / 12752
# FM progress: 239 / 12752
# FM progress: 240 / 12752
# FM progress: 241 / 12752
# FM progress: 242 / 12752
# FM progress: 243 / 12752
# FM progress: 244 / 12752
# FM progress: 245 / 12752
# FM progress: 246 / 12752
# FM progress: 247 / 12752
# FM progress: 248 / 12752
# FM progress: 249 / 12752
# FM progress: 250 / 12752
# FM progress: 251 / 12752
# FM progress: 252 / 12752
# FM progress: 253 / 12752
# FM progress: 254 / 12752
# FM progress: 255 / 12752
# FM progress: 256 / 12752
# FM progress: 257 / 12752
# FM progress: 258 / 12752
# FM progress: 259 / 12752
# FM progress: 260 / 12752
# FM progress: 261 / 12752
# FM progress: 262 / 12752
# FM progress: 263 / 12752
# FM progress: 264 / 12752
# FM progress: 265 / 12752
# FM progress: 266 / 12752
# FM progress: 267 / 12752
# FM progress: 268 / 12752
# FM progress: 269 / 12752
# FM progress: 270 / 12752
# FM progress: 271 / 12752
# FM progress: 272 / 12752
# FM progress: 273 / 12752
# FM progress: 274 / 12752
# FM progress: 275 / 12752
# FM progress: 276 / 12752
# FM progress: 277 / 12752
# FM progress: 278 / 12752
# FM progress: 279 / 12752
# FM progress: 280 / 12752
# FM progress: 281 / 12752
# FM progress: 282 / 12752
# FM progress: 283 / 12752
# FM progress: 284 / 12752
# FM progress: 285 / 12752
# FM progress: 286 / 12752
# FM progress: 287 / 12752
# FM progress: 288 / 12752
# FM progress: 289 / 12752
# FM progress: 290 / 12752
# FM progress: 291 / 12752
# FM progress: 292 / 12752
# FM progress: 293 / 12752
# FM progress: 294 / 12752
# FM progress: 295 / 12752
# FM progress: 296 / 12752
# FM progress: 297 / 12752
# FM progress: 298 / 12752
# FM progress: 299 / 12752
# FM progress: 300 / 12752
# FM progress: 301 / 12752
# FM progress: 302 / 12752
# FM progress: 303 / 12752
# FM progress: 304 / 12752
# FM progress: 305 / 12752
# FM progress: 306 / 12752
# FM progress: 307 / 12752
# FM progress: 308 / 12752
# FM progress: 309 / 12752
# FM progress: 310 / 12752
# FM progress: 311 / 12752
# FM progress: 312 / 12752
# FM progress: 313 / 12752
# FM progress: 314 / 12752
# FM progress: 315 / 12752
# FM progress: 316 / 12752
# FM progress: 317 / 12752
# FM progress: 318 / 12752
# FM progress: 319 / 12752
# FM progress: 320 / 12752
# FM progress: 321 / 12752
# FM progress: 322 / 12752
# FM progress: 323 / 12752
# FM progress: 324 / 12752
# FM progress: 325 / 12752
# FM progress: 326 / 12752
# FM progress: 327 / 12752
# FM progress: 328 / 12752
# FM progress: 329 / 12752
# FM progress: 330 / 12752
# FM progress: 331 / 12752
# FM progress: 332 / 12752
# FM progress: 333 / 12752
# FM progress: 334 / 12752
# FM progress: 335 / 12752
# FM progress: 336 / 12752
# FM progress: 337 / 12752
# FM progress: 338 / 12752
# FM progress: 339 / 12752
# FM progress: 340 / 12752
# FM progress: 341 / 12752
# FM progress: 342 / 12752
# FM progress: 343 / 12752
# FM progress: 344 / 12752
# FM progress: 345 / 12752
# FM progress: 346 / 12752
# FM progress: 347 / 12752
# FM progress: 348 / 12752
# FM progress: 349 / 12752
# FM progress: 350 / 12752
# FM progress: 351 / 12752
# FM progress: 352 / 12752
# FM progress: 353 / 12752
# FM progress: 354 / 12752
# FM progress: 355 / 12752
# FM progress: 356 / 12752
# FM progress: 357 / 12752
# FM progress: 358 / 12752
# FM progress: 359 / 12752
# FM progress: 360 / 12752
# FM progress: 361 / 12752
# FM progress: 362 / 12752
# FM progress: 363 / 12752
# FM progress: 364 / 12752
# FM progress: 365 / 12752
# FM progress: 366 / 12752
# FM progress: 367 / 12752
# FM progress: 368 / 12752
# FM progress: 369 / 12752
# FM progress: 370 / 12752
# FM progress: 371 / 12752
# FM progress: 372 / 12752
# FM progress: 373 / 12752
# FM progress: 374 / 12752
# FM progress: 375 / 12752
# FM progress: 376 / 12752
# FM progress: 377 / 12752
# FM progress: 378 / 12752
# FM progress: 379 / 12752
# FM progress: 380 / 12752
# FM progress: 381 / 12752
# FM progress: 382 / 12752
# FM progress: 383 / 12752
# FM progress: 384 / 12752
# FM progress: 385 / 12752
# FM progress: 386 / 12752
# FM progress: 387 / 12752
# FM progress: 388 / 12752
# FM progress: 389 / 12752
# FM progress: 390 / 12752
# FM progress: 391 / 12752
# FM progress: 392 / 12752
# FM progress: 393 / 12752
# FM progress: 394 / 12752
# FM progress: 395 / 12752
# FM progress: 396 / 12752
# FM progress: 397 / 12752
# FM progress: 398 / 12752
# FM progress: 399 / 12752
# FM progress: 400 / 12752
# FM progress: 401 / 12752
# FM progress: 402 / 12752
# FM progress: 403 / 12752
# FM progress: 404 / 12752
# FM progress: 405 / 12752
# FM progress: 406 / 12752
# FM progress: 407 / 12752
# FM progress: 408 / 12752
# FM progress: 409 / 12752
# FM progress: 410 / 12752
# FM progress: 411 / 12752
# FM progress: 412 / 12752
# FM progress: 413 / 12752
# FM progress: 414 / 12752
# FM progress: 415 / 12752
# FM progress: 416 / 12752
# FM progress: 417 / 12752
